# %%
Q1. What are the three measures of central tendency?
Ans:-The three measures of central tendency are:

1.Mean: The mean is the most commonly used measure of central tendency. It is calculated by adding up all the values in a dataset and 
  dividing the sum by the number of values.

2.Median: The median is the middle value in a dataset when the values are arranged in order from lowest to highest. If there are an even
  number of values, the median is the average of the two middle values.

3.Mode: The mode is the value that occurs most frequently in a dataset. In some datasets, there may be no mode, or there may be multiple 
  modes if more than one value occurs with the same highest frequency.

# %%
Q2. What is the difference between the mean, median, and mode? How are they used to measure the
central tendency of a dataset?
Ans:-The mean, median, and mode are all measures of central tendency, but they differ in how they describe the center of a dataset.

1.The mean is calculated by adding up all the values in a dataset and dividing the sum by the number of values. The mean is sensitive to 
  outliers because it takes into account all the values in the dataset. A single extreme value can have a large impact on the mean.

2.The median is the middle value in a dataset when the values are arranged in order from lowest to highest. The median is less sensitive 
  to outliers than the mean because it only depends on the values in the middle of the dataset. If there are an even number of values, 
  the median is the average of the two middle values.

3.The mode is the value that occurs most frequently in a dataset. The mode is useful for identifying the most common value or values in a 
  dataset, which can be helpful in some contexts.

All three measures are used to describe the central tendency of a dataset, but the choice of which measure to use depends on the 
characteristics of the data. The mean is often used for data that is normally distributed or has no extreme outliers. The median is 
useful for data with extreme outliers or a skewed distribution. The mode is useful for identifying the most common value or values in a
dataset, but it may not be representative of the entire dataset.

# %%
Q3. Measure the three measures of central tendency for the given height data:
[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

Ans:-1.Mean: The mean is calculated by adding up all the values in the dataset and dividing by the number of values.
      mean = (178+177+176+177+178.2+178+175+179+180+175+178.9+176.2+177+172.5+178+176.5) / 16
      mean = 177.65625
    So the mean height in the dataset is approximately 177.66
     
    2.Median: To find the median, we need to arrange the values in order from lowest to highest and find the middle value.
    172.5, 175, 175, 176, 176.2, 176.5, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180

    Since there are an even number of values, the median is the average of the two middle values, which are 177 and 178.

    median = (177 + 178) / 2
    median = 177.5

    So the median height in the dataset is approximately 177.5
    
    3.Mode: The mode is the value that occurs most frequently in the dataset.
      The value 178 occurs three times, which is more than any other value, so the mode of the dataset is 178.

    Therefore, the three measures of central tendency for the given height data are:

     Mean: 177.66
     Median: 177.5
     Mode: 178

# %%
Q4. Find the standard deviation for the given data:
[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

Ans:-
σ = sqrt [ Σ ( xi - μ )^2 / N ]

σ = sqrt [ 57.1021875 / 16 ]

σ = sqrt [ 3.56988671875 ]

σ = 1.88890455878 (rounded to 2 decimal places)

Therefore, the standard deviation of the given data is approximately 1.89.

# %%
Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe
the spread of a dataset? Provide an example.

Ans:- 1.Range:-The range of a dataset is the difference between the maximum and minimum values in the dataset. It gives an idea of how 
      spread out the data is from one end to another
     
    Ex:-Dataset 1: [10, 20, 30, 40, 50]
        Dataset 2: [10, 12, 15, 50, 60]
        
    Both datasets have the same mean of 30. However, the range of Dataset 1 is 40 (50-10), while the range of Dataset 2 is 50 (60-10).
    This means that the values in Dataset 2 are more spread out than those in Dataset 1.
    
    2.Variance & Standard Daviation :- It is calculated by taking the average of the squared deviations from the mean.
    
    Ex:-Dataset 1: [10, 20, 30, 40, 50]
        Dataset 2: [10, 12, 15, 50, 60]

    The variance of Dataset 1 is 250, and the standard deviation is approximately 15.81. The variance of Dataset 2 is 556.8, and the
    standard deviation is approximately 23.6. This means that the values in Dataset 2 are more spread out than those in Dataset 1, as
    the variance and standard deviation are higher.

# %%
Q6. What is a Venn diagram?
Ans:-A Venn diagram is a visual representation of the relationships between different sets of data. It consists of one or more circles or
     ovals that are used to represent different sets or categories, and the areas of overlap between the circles represent the elements 
     that belong to more than one set.

    Venn diagrams are often used to illustrate logical relationships between sets, such as intersections and unions. They are also used
    to visually organize and compare different groups of data, as well as to identify similarities and differences between them.

# %%
Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
(i) A B
(ii) A ⋃ B

Ans:-(i) A ∩ B (the intersection of A and B) represents the set of elements that are common to both A and B. In other words, it includes
      only those elements that belong to both sets A and B.

      To find the intersection of A and B, we need to identify the common elements in both sets, which are 2 and 6. Therefore,

      A ∩ B = {2, 6}

     (ii) A ⋃ B (the union of A and B) represents the set of elements that belong to either A or B, or to both. In other words, it includes
          all the elements that are in set A, set B, or both.

         To find the union of A and B, we need to combine all the elements in both sets without any duplicates. Therefore,

         A ⋃ B = {0, 2, 3, 4, 5, 6, 7, 8, 10}

# %%
Q8. What do you understand about skewness in data?
Ans:-Skewness is a measure of the asymmetry of a probability distribution or dataset. A distribution is said to be skewed if it is not
    symmetrical. In a symmetrical distribution, the mean, median, and mode are all equal. However, in a skewed distribution, these three
    measures of central tendency are not equal.

   Skewness can be positive, negative, or zero. A positive skew indicates that the tail of the distribution extends more to the right than 
   to the left, and the mean is greater than the median. In contrast, a negative skew indicates that the tail of the distribution extends
   more to the left than to the right, and the mean is less than the median. A zero skew indicates that the distribution is symmetrical, 
   and the mean, median, and mode are all equal.

# %%
Q9. If a data is right skewed then what will be the position of median with respect to mean?
Ans:-If a data distribution is right skewed, the mean will be greater than the median. This is because the skewed distribution has a
   long tail on the right side, which pulls the mean towards the right, away from the peak of the distribution. In contrast, the median 
   represents the middle value of the dataset and is less affected by extreme values or outliers. Therefore, in a right-skewed distribution,
   the median is usually closer to the left side of the distribution, where the majority of the data points are located.

# %%
Q10. Explain the difference between covariance and correlation. How are these measures used in
statistical analysis?
Ans:-Covariance and correlation are two statistical measures that are used to describe the relationship between two variables.

Covariance is a measure of the degree to which two variables vary together. It is calculated by taking the product of the deviations of
each variable from their respective means, and then averaging those products. A positive covariance indicates that the variables tend to
move in the same direction, while a negative covariance indicates that they tend to move in opposite directions. However, the magnitude 
of the covariance is dependent on the scale of the variables, which makes it difficult to compare covariances across different datasets.

Correlation, on the other hand, is a standardized measure of the relationship between two variables. It measures the strength and 
direction of the linear relationship between the two variables, regardless of their scale. Correlation values range from -1 to 1, where 
a value of -1 indicates a perfect negative correlation, 0 indicates no correlation, and 1 indicates a perfect positive correlation.

Correlation is preferred over covariance because it is a standardized measure that is easier to interpret and compare across different 
datasets. In statistical analysis, correlation is often used to determine the strength and direction of the relationship between two 
variables, while covariance is used to determine the joint variability of two variables. Correlation is also useful in predicting the
value of one variable based on the value of another variable, which is the basis of regression analysis.

# %%
Q11. What is the formula for calculating the sample mean? Provide an example calculation for a
dataset.
Ans:- The formula for calculating the sample mean is:

sample mean = (sum of all values in the sample) / (number of values in the sample)

For example, suppose we have the following dataset:

[3, 7, 9, 12, 15]

To find the sample mean of this dataset, we first add up all the values in the dataset:

3 + 7 + 9 + 12 + 15 = 46

Next, we divide the sum by the total number of values in the dataset, which is 5:

sample mean = 46 / 5 = 9.2

Therefore, the sample mean of this dataset is 9.2.

# %%
Q12. For a normal distribution data what is the relationship between its measure of central tendency?
Ans:- For a normal distribution, the measures of central tendency (mean, median, and mode) are all equal. This means that the center of
      the distribution is located at the same point regardless of which measure is used.

    This property is a characteristic of a symmetric distribution, where the data points are evenly distributed around the center of the
    distribution. In a normal distribution, the majority of the data points are located near the center of the distribution, while fewer
    points are located towards the tails of the distribution.

    Therefore, in a normal distribution, the mean, median, and mode are all located at the same point, which represents the center of the
    distribution. This also implies that the distribution is unimodal, with only one peak at the center of the distribution.

# %%
Q13. How is covariance different from correlation?
Ans:- Covariance and correlation are two statistical measures that describe the relationship between two variables. While they are 
related, they are different in a few key ways.

Covariance is a measure of the degree to which two variables vary together. It is calculated by taking the product of the deviations of
each variable from their respective means, and then averaging those products. A positive covariance indicates that the variables tend to 
move in the same direction, while a negative covariance indicates that they tend to move in opposite directions. However, the magnitude
of the covariance is dependent on the scale of the variables, which makes it difficult to compare covariances across different datasets.

Correlation, on the other hand, is a standardized measure of the relationship between two variables. It measures the strength and 
direction of the linear relationship between the two variables, regardless of their scale. Correlation values range from -1 to 1, where 
a value of -1 indicates a perfect negative correlation, 0 indicates no correlation, and 1 indicates a perfect positive correlation.

In other words, covariance measures the degree to which two variables vary together, while correlation measures the strength and
direction of the linear relationship between the two variables. Correlation is preferred over covariance because it is a standardized
measure that is easier to interpret and compare across different datasets. Correlation also provides more insight into the relationship 
between two variables than covariance, because it is not affected by the scale of the variables.

# %%
Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.
Ans:-Outliers can have a significant impact on measures of central tendency and dispersion. An outlier is an observation that is
significantly different from other observations in the dataset. Outliers can be caused by measurement error, data entry errors, or real
variations in the data.

In terms of measures of central tendency, outliers can significantly affect the mean but have little effect on the median or mode. This
is because the mean is sensitive to extreme values, while the median and mode are not. If a dataset has an outlier that is much higher 
or lower than the other values, the mean will be pulled towards that value, while the median and mode will not be affected.

In terms of measures of dispersion, outliers can significantly affect the range, variance, and standard deviation. This is because these 
measures are calculated based on the distance of each data point from the mean, and outliers can increase the variability of the dataset.
For example, a single outlier that is much higher than the other values can increase the range, variance, and standard deviation, making
these measures less representative of the bulk of the data.

For example, consider the following dataset of ages:

[22, 24, 25, 27, 28, 30, 35, 38, 39, 50]

The mean age of this dataset is 32.8, the median age is 29, and the mode is not applicable since there are no repeated values. If we add 
an outlier to this dataset, such as age 100, the mean age increases to 42.5, while the median age and mode remain unchanged. Similarly, 
the range increases from 28 to 78, and the variance and standard deviation increase as well, indicating that the dataset has become more
variable due to the outlier.
